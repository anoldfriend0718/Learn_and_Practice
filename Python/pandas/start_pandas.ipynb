# %%
import pandas as pd
pd.__version__
pd??

# %%
import numpy as np
np.__version__
# Out:
# '1.16.4'

# %%
#create a data frame - dictionary is used here where keys get converted to column names and values to row values.
data = pd.DataFrame({'Country': ['Russia','Colombia','Chile','Equador','Nigeria'],
                    'Rank':[121,40,100,130,11]})
data
# Out:
#     Country  Rank
# 0    Russia   121
# 1  Colombia    40
# 2     Chile   100
# 3   Equador   130
# 4   Nigeria    11

# %%
data2=pd.DataFrame({"name":["QianghuiXU"],"Rank":[1]})
data2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-43e2f357cc23> in <module>
# ----> 1 data2=pd.DataFrame({"name":("QianghuiXU"),"Rank":(1)})
#       2 data2
#
# c:\python\python37\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# c:\python\python37\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# --> 212     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     213
#     214
#
# ...

# %%
data.describe()
#Remember, describe() method computes summary statistics of integer / double variables. To get the complete information about the data set, we can use info() function.
# Out:
#              Rank
# count    5.000000
# mean    80.400000
# std     52.300096
# min     11.000000
# 25%     40.000000
# 50%    100.000000
# 75%    121.000000
# max    130.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
# Country    5 non-null object
# Rank       5 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 160.0+ bytes

# %%
data = pd.DataFrame({'group':['a', 'a', 'a', 'b','b', 'b', 'c', 'c','c'],'ounces':[4, 3, 12, 6, 7.5, 8, 3, 5, 6]})
data
# Out:
#   group  ounces
# 0     a     4.0
# 1     a     3.0
# 2     a    12.0
# 3     b     6.0
# 4     b     7.5
# 5     b     8.0
# 6     c     3.0
# 7     c     5.0
# 8     c     6.0

# %%
#Let's sort the data frame by ounces - inplace = True will make changes to the data#Let's sort the data frame by ounces - inplace = True will make changes to the data
data.sort_values(by=['ounces'],ascending=True,inplace=False)
# Out:
#   group  ounces
# 1     a     3.0
# 6     c     3.0
# 0     a     4.0
# 7     c     5.0
# 3     b     6.0
# 8     c     6.0
# 4     b     7.5
# 5     b     8.0
# 2     a    12.0

# %%
#We can sort the data by not just one column but multiple columns as well.
data.sort_values(by=['ounces',"group"],ascending=True,inplace=True)
data
# Out:
#   group  ounces
# 1     a     3.0
# 6     c     3.0
# 0     a     4.0
# 7     c     5.0
# 3     b     6.0
# 8     c     6.0
# 4     b     7.5
# 5     b     8.0
# 2     a    12.0

# %%
print(data["group"].unique())
# Out:
# ['a' 'c' 'b']

# %%
#create another data with duplicated rows
data = pd.DataFrame({"k1":["one"]*3+["two"]*4,"k2":[0,1,1,3,4,5,6]})
data
# Out:
#     k1  k2
# 0  one   0
# 1  one   1
# 2  one   2
# 3  two   3
# 4  two   4
# 5  two   5
# 6  two   6

# %%
data.drop_duplicates()
# Out:
#     k1  k2
# 0  one   0
# 1  one   1
# 2  one   2
# 3  two   3
# 4  two   4
# 5  two   5
# 6  two   6

# %%
data.drop_duplicates(subset="k1")
# Out:
#     k1  k2
# 0  one   0
# 3  two   3

# %%
data = pd.DataFrame({'food': ['bacon', 'pulled pork', 'bacon', 'Pastrami','corned beef', 'Bacon', 'pastrami', 'honey ham','nova lox'],
                 'ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})
data
# Out:
#           food  ounces
# 0        bacon     4.0
# 1  pulled pork     3.0
# 2        bacon    12.0
# 3     Pastrami     6.0
# 4  corned beef     7.5
# 5        Bacon     8.0
# 6     pastrami     3.0
# 7    honey ham     5.0
# 8     nova lox     6.0

# %%
meat_to_animal = {
'bacon': 'pig',
'pulled pork': 'pig',
'pastrami': 'cow',
'corned beef': 'cow',
'honey ham': 'pig',
'nova lox': 'salmon'
}
def meat_2_animal(series):
    return meat_to_animal[series["food"]]

data['animal'] = data['food'].map(str.lower).map(meat_to_animal)
data
# Out:
#           food  ounces  animal
# 0        bacon     4.0     pig
# 1  pulled pork     3.0     pig
# 2        bacon    12.0     pig
# 3     Pastrami     6.0     cow
# 4  corned beef     7.5     cow
# 5        Bacon     8.0     pig
# 6     pastrami     3.0     cow
# 7    honey ham     5.0     pig
# 8     nova lox     6.0  salmon

# %%
lower=lambda x:x.lower()
data["food"]=data["food"].apply(lower)
data['animal2'] = data.apply(meat_2_animal, axis='columns')
data
# Out:
#           food  ounces  animal animal2
# 0        bacon     4.0     pig     pig
# 1  pulled pork     3.0     pig     pig
# 2        bacon    12.0     pig     pig
# 3     pastrami     6.0     cow     cow
# 4  corned beef     7.5     cow     cow
# 5        bacon     8.0     pig     pig
# 6     pastrami     3.0     cow     cow
# 7    honey ham     5.0     pig     pig
# 8     nova lox     6.0  salmon  salmon

# %%
data.assign(new_variable=data["ounces"]*10)
# Out:
#           food  ounces  animal animal2  new_variable
# 0        bacon     4.0     pig     pig          40.0
# 1  pulled pork     3.0     pig     pig          30.0
# 2        bacon    12.0     pig     pig         120.0
# 3     pastrami     6.0     cow     cow          60.0
# 4  corned beef     7.5     cow     cow          75.0
# 5        bacon     8.0     pig     pig          80.0
# 6     pastrami     3.0     cow     cow          30.0
# 7    honey ham     5.0     pig     pig          50.0
# 8     nova lox     6.0  salmon  salmon          60.0

# %%
data.drop("animal2",axis="columns",inplace=True)
data
# Out:
#           food  ounces  animal
# 0        bacon     4.0     pig
# 1  pulled pork     3.0     pig
# 2        bacon    12.0     pig
# 3     pastrami     6.0     cow
# 4  corned beef     7.5     cow
# 5        bacon     8.0     pig
# 6     pastrami     3.0     cow
# 7    honey ham     5.0     pig
# 8     nova lox     6.0  salmon

# %%
data = pd.Series([1., -999., 2., -999., -1000., 3.])
data
# Out:
# 0       1.0
# 1    -999.0
# 2       2.0
# 3    -999.0
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
data.replace(-999, np.nan,inplace=True)
data
# Out:
# 0       1.0
# 1       NaN
# 2       2.0
# 3       NaN
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
data = pd.Series([1., -999., 2., -999., -1000., 3.])
data.replace([-999,-1000],np.nan,inplace=True)
data
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    NaN
# 5    3.0
# dtype: float64

# %%
data = pd.DataFrame(np.arange(12).reshape((3, 4)),index=['Ohio', 'Colorado', 'New York'],columns=['one', 'two', 'three', 'four'])
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# New York    8    9     10    11

# %%
data.rename(index={"Ohio":"SanF"},columns={"one":"one_p","two":"two_p"},inplace=True)
data
# Out:
#           one_p  two_p  three  four
# SanF          0      1      2     3
# Colorado      4      5      6     7
# New York      8      9     10    11

# %%
data.rename(index = str.upper, columns=str.title,inplace=True)
data
# Out:
#           One_P  Two_P  Three  Four
# SANF          0      1      2     3
# COLORADO      4      5      6     7
# NEW YORK      8      9     10    11
